# %%
#Python is created by Guido van Rossum in 1991
#Python is most popular programming language, interpreter, high level language because it is widely used in all sectors and very easily to learn and understand due to it's syntax is very simple.
#Python have OOP concepts as well as functional concepts.
#Python used in software development, data science, Machine learning, Automation,web development,cloud..etc

# %%
print("Hello World")
# Out:
# Hello World

# %%
num = 22
num
# Out:
# 22

# %%
type(num)
# Out:
# int

# %%
name = "Deepika"
name
# Out:
# 'Deepika'

# %%
type(name)
# Out:
# str

# %%
found = True
found
# Out:
# True

# %%
type(found)
# Out:
# bool

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
type(pi)
# Out:
# float

# %%
input("Enter your college name:")
# Out:
# Enter your college name: Aditya University
# 'Aditya University'

# %%
int(input("Enter your marks:"))
# Out:
# Enter your marks: 98
# 98

# %%
age = int(input("Enter your age:"))
print(age)
# Out:
# Enter your age: 12
# 12

# %%
Average_marks = float(input("Enter your avg:"))
print(Average_marks)
# Out:
# Enter your avg: 9.08
# 9.08

# %%
print("Loading",end="...")
# Out:
# Loading...

# %%
# name = "Aditya"                                 single comment
"""Hey hi all
welcome to my page
today we discuss about the python fundamentals""" #multiline comment

# %% [markdown]
# ## OPERATORS

# %% [markdown]
# # Arithmetic operators

# %%
a = 10
b = 20
a+b
# Out:
# 30

# %%
c = a + b
c
# Out:
# 30

# %%
a - b
# Out:
# -10

# %%
a / b
# Out:
# 0.5

# %%
a % b
# Out:
# 10

# %%
a * b
# Out:
# 200

# %%
a ** b
# Out:
# 100000000000000000000

# %% [markdown]
# # Assignment operator

# %%
x = 10
x
# Out:
# 10

# %%
x += 5
x
# Out:
# 15

# %%
y = 20
y
# Out:
# 20

# %%
y -= 7
y
# Out:
# 13

# %%
z = 8
z
# Out:
# 8

# %%
z *= 2
z
# Out:
# 16

# %%
d = 10
d
# Out:
# 10

# %%
d /= 2
d
# Out:
# 0.05

# %% [markdown]
# # Comparsion operator

# %%
#OUTPUT always in boolean format

# %%
a = 1
b = 2
print(a == b)
# Out:
# False

# %%
a = 1
b = 1
print(a == b)
# Out:
# True

# %%
a = 23
b = 32
print(a < b)
# Out:
# True

# %%
print(a > b)
# Out:
# False

# %%
print(a != b)
# Out:
# True

# %%
print(a <= b)
print(a >= b)
# Out:
# True
# False

# %% [markdown]
# # Logical operators

# %%
age = 19

# %%
vote = True

# %%
print(age > 18 and vote)
# Out:
# True

# %%
print(age < 18 or vote)
# Out:
# True

# %% [markdown]
# # Membership operator

# %%
movie = "Dear Comrade"

# %%
print("i" in movie)
# Out:
# False

# %%
print("d" in movie)
# Out:
# True

# %%
print("z" not in movie)
# Out:
# True

# %%
print("C" not in movie)
# Out:
# False

# %% [markdown]
# # Identity operator

# %%
nums1 = [1,2,3,4]  # is hep to check the same variable same object

# %%
nums2 = nums1

# %%
print(nums2)
# Out:
# [1, 2, 3, 4]

# %%
print(nums1 is nums2)
# Out:
# True

# %%
nums3 = [1,2,3,4]

# %%
print(nums2 is nums3)
# Out:
# False

# %%
print(nums1 is nums3)
# Out:
# False

# %%
print(nums1 == nums3)
# Out:
# True

# %% [markdown]
# # Bitwise operator

# %%
a = 3

# %%
b = 2

# %%
print(a & b)
# Out:
# 2

# %%
print(a | b)
# Out:
# 3

# %%
print(a ^ b)
# Out:
# 1

# %% [markdown]
# ## STRINGS operators

# %%
name = "Hi all, my Name is Deepika Bora"

# %%
print(name)
# Out:
# Hi all, my Name is Deepika Bora

# %%
print(len(name))
# Out:
# 31

# %%
print(name.upper())
# Out:
# HI ALL, MY NAME IS DEEPIKA BORA

# %%
print(name.lower())
# Out:
# hi all, my name is deepika bora

# %%
print(name.title())
# Out:
# Hi All, My Name Is Deepika Bora

# %%
print(name.strip())
# Out:
# Hi all, my Name is Deepika Bora

# %%
print(name.split("'"))
# Out:
# ['Hi all, my Name is Deepika Bora']

# %%
print(name.replace("Hi","Hello"))
# Out:
# Hello all, my Name is Deepika Bora

# %%
print(name.count("a"))
# Out:
# 4

# %%
print(name.find("Deepika"))
# Out:
# 19

# %% [markdown]
# # Slicing

# %%
text = "Python Programming"

# %%
print(text[0])
# Out:
# P

# %%
print(text[0:19])
# Out:
# Python Programming

# %%
print(text[3:])
# Out:
# hon Programming

# %%
print(text[::-1])
# Out:
# gnimmargorP nohtyP

# %%
print(text[2:-6])
# Out:
# thon Progr

# %%
print(text[0:7])
# Out:
# Python

# %%
print(text[7:19])
# Out:
# Programming

# %%
print(text[0:-12])
# Out:
# Python

# %% [markdown]
# # Formatting strings

# %%
name = input("Enter you name:")
age = int(input("Enter your age:"))
print(f"My name is {name} and i am {age} old")
# Out:
# Enter you name: mani
# Enter your age: 43
# My name is mani and i am 43 old
